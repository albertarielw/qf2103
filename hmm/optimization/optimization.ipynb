# %%
import numpy as np
from hmmlearn import hmm
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC

# %% [markdown]
# # 1. Utils

# %%
# Calculate the accuracy of prediction
def calculate_accuracy(prediction, test):
    prediction = pd.DataFrame(prediction)
    test = pd.DataFrame(test)

    return (prediction == test).sum() / len(prediction)

def calculate_return(prediction, log_rets):
    return (pd.DataFrame(prediction) * pd.DataFrame(log_rets)).sum()

# read csv files and add relevant columns
# if add_direction_col is True, add a prediction column -> indicating tomorrow's price will rise or fall
# if add_original_price_col is True, save original stock_price as a col -> necessary to keep original price after normalization
def prepare_data(filename, stockname='', add_original_price_col=True, add_log_rets=True, add_direction_col=True):
    df = pd.read_csv(filename, index_col=0, parse_dates=True)
    
    if add_original_price_col:
        df['price'] = df[stockname]

    # note that our log_rets is shifted up by 1 compared to lecture
    # this is to facilitate easier calculation of our strategy
    # our log ret implementation -> log of (tomorrow's price / today's price)
    # thus, log_rets * prediction will give the return of today's trading decision (long or short) based on prediction
    if add_log_rets:
        df['log_rets'] = np.log(df[stockname].shift(-1) / df[stockname])

    # note that if this is true, prediction will be right-most col
    if add_direction_col:
        df['direction'] = np.where(df[stockname] <= df[stockname].shift(-1), 1, -1)
    
    return df

# Split data sequentially into X_train, y_train, X_test, y_test (assuming y is right-most col) based on given ration
def sequential_train_test_split(data, ratio = 0.8, get_log_rets=True):
    data = data.dropna()
    df = pd.DataFrame(data.drop(columns=['price', 'log_rets'])).to_numpy()

    # note that we exclude price and log_rets return in our training as they are not normalized
    # they are not normalized as we need their original values for return calculation
    split_index = int(len(df) * ratio)
    train_data, test_data = df[:split_index], df[split_index:]
    X_train, y_train, X_test, y_test = train_data[:, :-1], train_data[:, -1], test_data[:, :-1], test_data[:, -1]

    if get_log_rets:
        log_rets_df = data['log_rets'].to_numpy()
        _, log_rets = log_rets_df[:split_index], log_rets_df[split_index:]
        return X_train, y_train, X_test, y_test, log_rets

    return X_train, y_train, X_test, y_test

# %%
data = prepare_data('./data/apple.csv', 'AAPL.O', add_original_price_col=True, add_log_rets=True, add_direction_col=True)
data
# Out:
#                 AAPL.O    SlowK    SlowD      RSI      ADX       CCI  \
# Date
# 2010-01-01         NaN      NaN      NaN      NaN      NaN       NaN
# 2010-04-01   30.572827  78.7484  82.8722  75.0702  38.0954   96.8893
# 2010-05-01   30.625684      NaN      NaN      NaN      NaN       NaN
# 2010-06-01   30.138541  89.5060  82.1665  57.5986  35.3551  151.4643
# 2010-07-01   30.082827  11.7287  14.7644  38.9499  24.7259 -152.8759
# ...                ...      ...      ...      ...      ...       ...
# 2018-06-25  182.170000  24.7765  28.7326  33.5305  28.2742 -132.0057
# 2018-06-26  184.430000  30.9769  28.9171  32.5318  28.2014  -70.9622
# 2018-06-27  184.160000  37.4891  31.0808  42.8627  27.4502  -43.5508
# 2018-06-28  185.500000  55.4647  41.3102  39.4747  26.9167  -30.3030
# 2018-06-29  185.110000  61.5693  51.5077  48.2783  25.4782  -22.6330
#
#             Aroon Down  Aroon Up           OBV   Chaikin A/D      SMA  \
# Date
# 2010-01-01         NaN       NaN           NaN           NaN      NaN
# 2010-04-01     42.8571  100.0000  8.816356e+10  5.524930e+10   6.9552
# 2010-05-01         NaN       NaN           NaN           NaN      NaN
# 2010-06-01     57.1429  100.0000  8.681483e+10  6.043320e+10   7.5207
# 2010-07-01    100.0000   42.8571  8.390127e+10  5.897666e+10   8.1018
# ...                ...       ...           ...           ...      ...
# 2018-06-25    100.0000   14.2857  9.108196e+10  7.277260e+10  44.7743
# 2018-06-26     92.8571    7.1429  9.118024e+10  7.276743e+10  44.5744
# 2018-06-27     85.7143    0.0000  9.107910e+10  7.267438e+10  44.4033
# 2018-06-28     78.5714   21.4286  9.114856e+10  7.270291e+10  44.2260
# 2018-06-29     71.4286   14.2857  9.105761e+10  7.270546e+10  44.1370
#
#                 EMA       price  log_rets  direction
# Date
# 2010-01-01      NaN         NaN       NaN         -1
# 2010-04-01   6.9908   30.572827  0.001727          1
# 2010-05-01      NaN   30.625684 -0.016034         -1
# 2010-06-01   7.6163   30.138541 -0.001850         -1
# 2010-07-01   7.9595   30.082827  0.006626          1
# ...             ...         ...       ...        ...
# 2018-06-25  44.5714  182.170000  0.012330          1
# 2018-06-26  44.3849  184.430000 -0.001465         -1
# 2018-06-27  44.3292  184.160000  0.007250          1
# 2018-06-28  44.2348  185.500000 -0.002105         -1
# 2018-06-29  44.2523  185.110000       NaN         -1
#
# [2216 rows x 15 columns]

# %% [markdown]
# # 2. Normalization

# %%
def normalize(df, exclude_columns = []):
    scaler = MinMaxScaler()

    for i in range(len(df.columns)):
        if df.columns[i] in exclude_columns:
            continue

        normalized_columns = scaler.fit_transform(pd.DataFrame(df.iloc[:, i]))
        df.iloc[:, i] = normalized_columns

    return df

# %%
data = normalize(data, ['price', 'log_rets', 'direction'])
data
# Out:
#               AAPL.O     SlowK     SlowD       RSI       ADX       CCI  \
# Date
# 2010-01-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2010-04-01  0.018837  0.797082  0.851941  0.769280  0.413634  0.658869
# 2010-05-01  0.019154       NaN       NaN       NaN       NaN       NaN
# 2010-06-01  0.016229  0.907128  0.844247  0.536156  0.374250  0.748379
# 2010-07-01  0.015895  0.111497  0.109400  0.287327  0.221484  0.249224
# ...              ...       ...       ...       ...       ...       ...
# 2018-06-25  0.929088  0.244971  0.261688  0.215016  0.272481  0.283454
# 2018-06-26  0.942658  0.308398  0.263699  0.201690  0.271435  0.383573
# 2018-06-27  0.941037  0.375016  0.287289  0.339535  0.260639  0.428531
# 2018-06-28  0.949083  0.558899  0.398814  0.294329  0.252971  0.450259
# 2018-06-29  0.946741  0.621347  0.509992  0.411795  0.232297  0.462838
#
#             Aroon Down  Aroon Up       OBV  Chaikin A/D       SMA       EMA  \
# Date
# 2010-01-01         NaN       NaN       NaN          NaN       NaN       NaN
# 2010-04-01    0.428571  1.000000  0.466485     0.197673  0.021918  0.021476
# 2010-05-01         NaN       NaN       NaN          NaN       NaN       NaN
# 2010-06-01    0.571429  1.000000  0.417465     0.386577  0.033742  0.034488
# 2010-07-01    1.000000  0.428571  0.311572     0.333500  0.045891  0.041627
# ...                ...       ...       ...          ...       ...       ...
# 2018-06-25    1.000000  0.142857  0.572554     0.836229  0.812646  0.803231
# 2018-06-26    0.928571  0.071429  0.576126     0.836040  0.808467  0.799351
# 2018-06-27    0.857143  0.000000  0.572450     0.832650  0.804889  0.798193
# 2018-06-28    0.785714  0.214286  0.574974     0.833689  0.801182  0.796229
# 2018-06-29    0.714286  0.142857  0.571669     0.833782  0.799321  0.796593
#
#                  price  log_rets  direction
# Date
# 2010-01-01         NaN       NaN         -1
# 2010-04-01   30.572827  0.001727          1
# 2010-05-01   30.625684 -0.016034         -1
# 2010-06-01   30.138541 -0.001850         -1
# 2010-07-01   30.082827  0.006626          1
# ...                ...       ...        ...
# 2018-06-25  182.170000  0.012330          1
# 2018-06-26  184.430000 -0.001465         -1
# 2018-06-27  184.160000  0.007250          1
# 2018-06-28  185.500000 -0.002105         -1
# 2018-06-29  185.110000       NaN         -1
#
# [2216 rows x 15 columns]

# %% [markdown]
# # 3. Optimization: Machine Learning Model Selection, Feature Selection, Hyperparameters Tuning

# %%
def benchmark(model_name, model, log_rets, X_train, y_train, X_test, y_test):
    pred = model.fit(X_train, y_train).predict(X_test)
    acc = calculate_accuracy(pred, y_test)[0]
    log_ret = calculate_return(pred, log_rets)[0]
    up_percentage = ((pred > 0).sum() / len(pred))
    simple_ret = np.exp(log_ret)
    print(f"{model_name}\naccuracy: {acc}\nlog_return: {log_ret}\nsimple_return: {simple_ret}\n up%: {up_percentage}")
    return acc, log_ret, simple_ret

# %%
X_train, y_train, X_test, y_test, log_rets = sequential_train_test_split(data)
print(len(y_test))
print(len(log_rets))
# Out:
# 363
# 363

# %% [markdown]
# ## 3.1 Machine Learning Model Selection

# %%
# linear model is excluded due non-linear-separability of data which leads to linear model to always predict all up or all down
model_name = 'SVC Linear Model'
model = SVC(kernel='linear')
benchmark(model_name, model, log_rets, X_train, y_train, X_test, y_test)

model_name = 'SVC Gaussian Model'
model = SVC(kernel='rbf')
benchmark(model_name, model, log_rets, X_train, y_train, X_test, y_test)

model_name = 'SVC Gaussian Model'
model = SVC(kernel='poly')
benchmark(model_name, model, log_rets, X_train, y_train, X_test, y_test)

model_name = 'SVC Sigmoid Model'
model = SVC(kernel='sigmoid', degree=2, C=3/10)
benchmark(model_name, model, log_rets, X_train, y_train, X_test, y_test)
# Out:
# SVC Linear Model
# accuracy: 0.4986225895316804
# log_return: 0.24198995575396315
# simple_return: 1.2737813985781763
#
# SVC Gaussian Model
# accuracy: 0.46831955922865015
# log_return: -0.4840671360067562
# simple_return: 0.6162718264939079
#
# SVC Gaussian Model
# accuracy: 0.5206611570247934
# log_return: -0.12894069878822068
# simple_return: 0.8790260913124078
#
# SVC Sigmoid Model
# accuracy: 0.4738292011019284
# log_return: -0.4764104347959125
# simple_return: 0.6210085464177639
# (0.4738292011019284, -0.4764104347959125, 0.6210085464177639)

# %% [markdown]
# ## 3.2 Feature Selection

# %%
import itertools

all_features = list(range(len(data.columns) - 3))

best_acc = 0
best_selected_features_for_acc = []

best_ret = 0
best_selected_features_for_ret = []

for i in range(1, len(data.columns) - 3):
    possible_selected_features = list(itertools.combinations(all_features, i))
    for selected_features in possible_selected_features:
        print("---")
        curr_X_train = X_train[:, selected_features].reshape(-1, len(selected_features))
        curr_X_test = X_test[:, selected_features].reshape(-1, len(selected_features))
        model = SVC(kernel='poly', degree = 2, C= 0.3)
        acc, log_ret, simple_ret = benchmark(f"SVC Poly with Features: {selected_features}", model, log_rets, curr_X_train, y_train, curr_X_test, y_test)

        if acc > best_acc:
            best_acc = acc
            best_selected_features_for_acc = selected_features

        if log_ret > best_ret:
            best_ret = log_ret
            best_selected_features_for_ret = selected_features

        print(f"Current Best Acc: {best_selected_features_for_acc} acc: {best_acc}")
        print(f"Current Best Ret: {best_selected_features_for_ret} log ret: {best_ret} simple ret: {np.exp(best_ret)}")
        print("---")

print(f"Overall Best Acc: {best_selected_features_for_acc} acc: {best_acc}")
print(f"Overall Best Ret: {best_selected_features_for_ret} log ret: {best_ret} simple ret: {np.exp(best_ret)}")
# Out:
# ---
# SVC Poly with Features: (0,)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (0,) acc: 0.5013774104683195
# Current Best Ret: (0,) log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with Features: (1,)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (0,) acc: 0.5013774104683195
# Current Best Ret: (0,) log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with Features: (2,)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (0,) acc: 0.5013774104683195
# Current Best Ret: (0,) log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with Features: (3,)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (0,) acc: 0.5013774104683195
# Current Best Ret: (0,) log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with Features: (4,)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (0,) acc: 0.5013774104683195
# Current Best Ret: (0,) log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with Features: (5,)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (0,) acc: 0.5013774104683195
# Current Best Ret: (0,) log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with Features: (6,)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (0,) acc: 0.5013774104683195
# Current Best Ret: (0,) log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with Features: (7,)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (0,) acc: 0.5013774104683195
# Current Best Ret: (0,) log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with Features: (8,)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (0,) acc: 0.5013774104683195
# Current Best Ret: (0,) log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with Features: (9,)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (0,) acc: 0.5013774104683195
# Current Best Ret: (0,) log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with Features: (10,)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (0,) acc: 0.5013774104683195
# Current Best Ret: (0,) log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with Features: (11,)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (0,) acc: 0.5013774104683195
# Current Best Ret: (0,) log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with Features: (0, 1)
# accuracy: 0.49586776859504134
# log_return: -0.25265425471540404
# simple_return: 0.776736388347276
#
# Current Best Acc: (0,) acc: 0.5013774104683195
# Current Best Ret: (0,) log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with Features: (0, 2)
# accuracy: 0.5041322314049587
# log_return: -0.035612427316487436
# simple_return: 0.9650142341702095
#
# Current Best Acc: (0, 2) acc: 0.5041322314049587
# Current Best Ret: (0,) log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with Features: (0, 3)
# accuracy: 0.512396694214876
# log_return: -0.13283384615570026
# simple_return: 0.8756105660845708
#
# Current Best Acc: (0, 3) acc: 0.512396694214876
# Current Best Ret: (0,) log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with Features: (0, 4)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (0, 3) acc: 0.512396694214876
# Current Best Ret: (0,) log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with Features: (0, 5)
# accuracy: 0.5179063360881543
# log_return: -0.1730559259396613
# simple_return: 0.8410905747485216
#
# Current Best Acc: (0, 5) acc: 0.5179063360881543
# Current Best Ret: (0,) log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with Features: (0, 6)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (0, 5) acc: 0.5179063360881543
# Current Best Ret: (0,) log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with Features: (0, 7)
# accuracy: 0.512396694214876
# log_return: 0.01799546081110251
# simple_return: 1.0181583547662048
#
# Current Best Acc: (0, 5) acc: 0.5179063360881543
# Current Best Ret: (0,) log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with Features: (0, 8)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (0, 5) acc: 0.5179063360881543
# Current Best Ret: (0,) log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with Features: (0, 9)
# accuracy: 0.5041322314049587
# log_return: -0.058013780401751425
# simple_return: 0.943636943651009
#
# Current Best Acc: (0, 5) acc: 0.5179063360881543
# Current Best Ret: (0,) log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with Features: (0, 10)
# accuracy: 0.509641873278237
# log_return: -0.1304971996547659
# simple_return: 0.877658950693357
#
# Current Best Acc: (0, 5) acc: 0.5179063360881543
# Current Best Ret: (0,) log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with Features: (0, 11)
# accuracy: 0.5068870523415978
# log_return: -0.14407705819312105
# simple_return: 0.8658210268846335
#
# Current Best Acc: (0, 5) acc: 0.5179063360881543
# Current Best Ret: (0,) log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with Features: (1, 2)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (0, 5) acc: 0.5179063360881543
# Current Best Ret: (0,) log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with Features: (1, 3)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (0, 5) acc: 0.5179063360881543
# Current Best Ret: (0,) log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with Features: (1, 4)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (0, 5) acc: 0.5179063360881543
# Current Best Ret: (0,) log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with Features: (1, 5)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (0, 5) acc: 0.5179063360881543
# Current Best Ret: (0,) log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with Features: (1, 6)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (0, 5) acc: 0.5179063360881543
# Current Best Ret: (0,) log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with Features: (1, 7)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (0, 5) acc: 0.5179063360881543
# Current Best Ret: (0,) log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with Features: (1, 8)
# accuracy: 0.5261707988980716
# log_return: 0.5523365136165108
# simple_return: 1.737307522001999
#
# Current Best Acc: (1, 8) acc: 0.5261707988980716
# Current Best Ret: (1, 8) log ret: 0.5523365136165108 simple ret: 1.737307522001999
# ---
# ---
# SVC Poly with Features: (1, 9)
# accuracy: 0.5426997245179064
# log_return: 0.5702387832867993
# simple_return: 1.7686893344672743
#
# Current Best Acc: (1, 9) acc: 0.5426997245179064
# Current Best Ret: (1, 9) log ret: 0.5702387832867993 simple ret: 1.7686893344672743
# ---
# ---
# SVC Poly with Features: (1, 10)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (1, 9) acc: 0.5426997245179064
# Current Best Ret: (1, 9) log ret: 0.5702387832867993 simple ret: 1.7686893344672743
# ---
# ---
# SVC Poly with Features: (1, 11)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (1, 9) acc: 0.5426997245179064
# Current Best Ret: (1, 9) log ret: 0.5702387832867993 simple ret: 1.7686893344672743
# ---
# ---
# SVC Poly with Features: (2, 3)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (1, 9) acc: 0.5426997245179064
# Current Best Ret: (1, 9) log ret: 0.5702387832867993 simple ret: 1.7686893344672743
# ---
# ---
# SVC Poly with Features: (2, 4)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (1, 9) acc: 0.5426997245179064
# Current Best Ret: (1, 9) log ret: 0.5702387832867993 simple ret: 1.7686893344672743
# ---
# ---
# SVC Poly with Features: (2, 5)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (1, 9) acc: 0.5426997245179064
# Current Best Ret: (1, 9) log ret: 0.5702387832867993 simple ret: 1.7686893344672743
# ---
# ---
# SVC Poly with Features: (2, 6)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (1, 9) acc: 0.5426997245179064
# Current Best Ret: (1, 9) log ret: 0.5702387832867993 simple ret: 1.7686893344672743
# ---
# ---
# SVC Poly with Features: (2, 7)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (1, 9) acc: 0.5426997245179064
# Current Best Ret: (1, 9) log ret: 0.5702387832867993 simple ret: 1.7686893344672743
# ---
# ---
# SVC Poly with Features: (2, 8)
# accuracy: 0.5399449035812672
# log_return: 0.6360795933465633
# simple_return: 1.8890604580860335
#
# Current Best Acc: (1, 9) acc: 0.5426997245179064
# Current Best Ret: (2, 8) log ret: 0.6360795933465633 simple ret: 1.8890604580860335
# ---
# ---
# SVC Poly with Features: (2, 9)
# accuracy: 0.5179063360881543
# log_return: 0.4696322523357288
# simple_return: 1.599405907266979
#
# Current Best Acc: (1, 9) acc: 0.5426997245179064
# Current Best Ret: (2, 8) log ret: 0.6360795933465633 simple ret: 1.8890604580860335
# ---
# ---
# SVC Poly with Features: (2, 10)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (1, 9) acc: 0.5426997245179064
# Current Best Ret: (2, 8) log ret: 0.6360795933465633 simple ret: 1.8890604580860335
# ---
# ---
# SVC Poly with Features: (2, 11)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (1, 9) acc: 0.5426997245179064
# Current Best Ret: (2, 8) log ret: 0.6360795933465633 simple ret: 1.8890604580860335
# ---
# ---
# SVC Poly with Features: (3, 4)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (1, 9) acc: 0.5426997245179064
# Current Best Ret: (2, 8) log ret: 0.6360795933465633 simple ret: 1.8890604580860335
# ---
# ---
# SVC Poly with Features: (3, 5)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (1, 9) acc: 0.5426997245179064
# Current Best Ret: (2, 8) log ret: 0.6360795933465633 simple ret: 1.8890604580860335
# ---
# ---
# SVC Poly with Features: (3, 6)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (1, 9) acc: 0.5426997245179064
# Current Best Ret: (2, 8) log ret: 0.6360795933465633 simple ret: 1.8890604580860335
# ---
# ---
# SVC Poly with Features: (3, 7)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (1, 9) acc: 0.5426997245179064
# Current Best Ret: (2, 8) log ret: 0.6360795933465633 simple ret: 1.8890604580860335
# ---
# ---
# SVC Poly with Features: (3, 8)
# accuracy: 0.5206611570247934
# log_return: 0.5229496452439321
# simple_return: 1.6869963589182593
#
# Current Best Acc: (1, 9) acc: 0.5426997245179064
# Current Best Ret: (2, 8) log ret: 0.6360795933465633 simple ret: 1.8890604580860335
# ---
# ---
# SVC Poly with Features: (3, 9)
# accuracy: 0.5179063360881543
# log_return: 0.43983188159771935
# simple_return: 1.5524462017960217
#
# Current Best Acc: (1, 9) acc: 0.5426997245179064
# Current Best Ret: (2, 8) log ret: 0.6360795933465633 simple ret: 1.8890604580860335
# ---
# ---
# SVC Poly with Features: (3, 10)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (1, 9) acc: 0.5426997245179064
# Current Best Ret: (2, 8) log ret: 0.6360795933465633 simple ret: 1.8890604580860335
# ---
# ---
# SVC Poly with Features: (3, 11)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (1, 9) acc: 0.5426997245179064
# Current Best Ret: (2, 8) log ret: 0.6360795933465633 simple ret: 1.8890604580860335
# ---
# ---
# SVC Poly with Features: (4, 5)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (1, 9) acc: 0.5426997245179064
# Current Best Ret: (2, 8) log ret: 0.6360795933465633 simple ret: 1.8890604580860335
# ---
# ---
# SVC Poly with Features: (4, 6)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (1, 9) acc: 0.5426997245179064
# Current Best Ret: (2, 8) log ret: 0.6360795933465633 simple ret: 1.8890604580860335
# ---
# ---
# SVC Poly with Features: (4, 7)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (1, 9) acc: 0.5426997245179064
# Current Best Ret: (2, 8) log ret: 0.6360795933465633 simple ret: 1.8890604580860335
# ---
# ---
# SVC Poly with Features: (4, 8)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (1, 9) acc: 0.5426997245179064
# Current Best Ret: (2, 8) log ret: 0.6360795933465633 simple ret: 1.8890604580860335
# ---
# ---
# SVC Poly with Features: (4, 9)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (1, 9) acc: 0.5426997245179064
# Current Best Ret: (2, 8) log ret: 0.6360795933465633 simple ret: 1.8890604580860335
# ---
# ---
# SVC Poly with Features: (4, 10)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (1, 9) acc: 0.5426997245179064
# Current Best Ret: (2, 8) log ret: 0.6360795933465633 simple ret: 1.8890604580860335
# ---
# ---
# SVC Poly with Features: (4, 11)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (1, 9) acc: 0.5426997245179064
# Current Best Ret: (2, 8) log ret: 0.6360795933465633 simple ret: 1.8890604580860335
# ---
# ---
# SVC Poly with Features: (5, 6)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (1, 9) acc: 0.5426997245179064
# Current Best Ret: (2, 8) log ret: 0.6360795933465633 simple ret: 1.8890604580860335
# ---
# ---
# SVC Poly with Features: (5, 7)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (1, 9) acc: 0.5426997245179064
# Current Best Ret: (2, 8) log ret: 0.6360795933465633 simple ret: 1.8890604580860335
# ---
# ---
# SVC Poly with Features: (5, 8)
# accuracy: 0.5151515151515151
# log_return: 0.46640272611073075
# simple_return: 1.594248915746937
#
# Current Best Acc: (1, 9) acc: 0.5426997245179064
# Current Best Ret: (2, 8) log ret: 0.6360795933465633 simple ret: 1.8890604580860335
# ---
# ---
# SVC Poly with Features: (5, 9)
# accuracy: 0.559228650137741
# log_return: 0.6454773027158256
# simple_return: 1.9068969792008335
#
# Current Best Acc: (5, 9) acc: 0.559228650137741
# Current Best Ret: (5, 9) log ret: 0.6454773027158256 simple ret: 1.9068969792008335
# ---
# ---
# SVC Poly with Features: (5, 10)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (5, 9) acc: 0.559228650137741
# Current Best Ret: (5, 9) log ret: 0.6454773027158256 simple ret: 1.9068969792008335
# ---
# ---
# SVC Poly with Features: (5, 11)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (5, 9) acc: 0.559228650137741
# Current Best Ret: (5, 9) log ret: 0.6454773027158256 simple ret: 1.9068969792008335
# ---
# ---
# SVC Poly with Features: (6, 7)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (5, 9) acc: 0.559228650137741
# Current Best Ret: (5, 9) log ret: 0.6454773027158256 simple ret: 1.9068969792008335
# ---
# ---
# SVC Poly with Features: (6, 8)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (5, 9) acc: 0.559228650137741
# Current Best Ret: (5, 9) log ret: 0.6454773027158256 simple ret: 1.9068969792008335
# ---
# ---
# SVC Poly with Features: (6, 9)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (5, 9) acc: 0.559228650137741
# Current Best Ret: (5, 9) log ret: 0.6454773027158256 simple ret: 1.9068969792008335
# ---
# ---
# SVC Poly with Features: (6, 10)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (5, 9) acc: 0.559228650137741
# Current Best Ret: (5, 9) log ret: 0.6454773027158256 simple ret: 1.9068969792008335
# ---
# ---
# SVC Poly with Features: (6, 11)
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#
# Current Best Acc: (5, 9) acc: 0.559228650137741
# Current Best Ret: (5, 9) log ret: 0.6454773027158256 simple ret: 1.9068969792008335
# ---
# ---
# SVC Poly with Features: (7, 8)
# accuracy: 0.4765840220385675
# log_return: 0.046823230257878046
# simple_return: 1.0479367491970515
#
# Current Best Acc: (5, 9) acc: 0.559228650137741
# Current Best Ret: (5, 9) log ret: 0.6454773027158256 simple ret: 1.9068969792008335
# ---
# ---
# SVC Poly with Features: (7, 9)
# accuracy: 0.47107438016528924
# log_return: 0.06351323821088328
# simple_return: 1.0655735919960188
#
# Current Best Acc: (5, 9) acc: 0.559228650137741
# Current Best Ret: (5, 9) log ret: 0.6454773027158256 simple ret: 1.9068969792008335
# ---
# ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[155], line 18
#      16 curr_X_test = X_test[:, selected_features].reshape(-1, len(selected_features))
#      17 model = SVC(kernel='poly', degree = 2, C= 0.3)
# ---> 18 acc, log_ret, simple_ret = benchmark(f"SVC Poly with Features: {selected_features}", model, log_rets, curr_X_train, y_train, curr_X_test, y_test)
#      20 if acc > best_acc:
#      21     best_acc = acc
#
# Cell In[138], line 3, in benchmark(model_name, model, log_rets, X_train, y_train, X_test, y_test)
#       1 def benchmark(model_name, model, log_rets, X_train, y_train, X_test, y_test):
#       2     pred = model.fit(X_train, y_train).predict(X_test)
# ----> 3     acc = calculate_accuracy(pred, y_test)[0]
#       4     log_ret = calculate_return(pred, log_rets)[0]
#       5     simple_ret = np.exp(log_ret)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/series.py:1040, in Series.__getitem__(self, key)
#    1037     return self._values[key]
#    1039 elif key_is_scalar:
# -> 1040     return self._get_value(key)
#    1042 # Convert generator to list before going through hashable part
#    1043 # (We will iterate through the generator there to check for slices)
#    1044 if is_iterator(key):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/series.py:1156, in Series._get_value(self, label, takeable)
#    1153     return self._values[label]
#    1155 # Similar to Index.get_value, but we do not fall back to positional
# -> 1156 loc = self.index.get_loc(label)
#    1158 if is_integer(loc):
#    1159     return self._values[loc]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/range.py:414, in RangeIndex.get_loc(self, key)
#     412 new_key = int(key)
#     413 try:
# --> 414     return self._range.index(new_key)
#     415 except ValueError as err:
#     416     raise KeyError(key) from err
#
# KeyboardInterrupt:

# %% [markdown]
# ## 3.3 Hyperparameter Tuning

# %%
import itertools

all_features = list(range(len(data.columns) - 3))

best_acc = 0
best_degree_for_acc = -1
best_C_for_acc = -1

best_ret = 0
best_degree_for_ret= -1
best_C_for_ret = -1

for d in range(1, 11):
    for c in range(1, 101, 1):
        degree = d
        C = c / 10

        print("---")
        model = SVC(kernel='poly', degree = degree, C = C)
        acc, log_ret, simple_ret = benchmark(f"SVC Poly with degree: {degree} C: {C}", model, log_rets, X_train, y_train, X_test, y_test)

        if acc > best_acc:
            best_acc = acc
            best_degree_for_acc = degree
            best_C_for_acc = C

        if log_ret > best_ret:
            best_ret = log_ret
            best_degree_for_ret= degree
            best_C_for_ret = C

        # print(f"Current Best Acc: degree: {best_degree_for_acc} C: {best_C_for_acc} acc: {best_acc}")
        print(d, C)
        print(f"Current Best Ret: degree: {best_degree_for_ret} C: {best_C_for_ret} log ret: {best_ret} simple ret: {np.exp(best_ret)}")
        print("---")

print(f"Overall Best Acc: degree: {best_degree_for_acc} C: {best_C_for_acc} acc: {best_acc}")
print(f"Overall Best Ret: degree: {best_degree_for_ret} C: {best_C_for_ret} log ret: {best_ret} simple ret: {np.exp(best_ret)}")
# Out:
# ---
# SVC Poly with degree: 1 C: 0.1
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#  up%: 1.0
# 1 0.1
# Current Best Ret: degree: 1 C: 0.1 log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with degree: 1 C: 0.2
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#  up%: 1.0
# 1 0.2
# Current Best Ret: degree: 1 C: 0.1 log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with degree: 1 C: 0.3
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#  up%: 1.0
# 1 0.3
# Current Best Ret: degree: 1 C: 0.1 log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with degree: 1 C: 0.4
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#  up%: 1.0
# 1 0.4
# Current Best Ret: degree: 1 C: 0.1 log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with degree: 1 C: 0.5
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#  up%: 1.0
# 1 0.5
# Current Best Ret: degree: 1 C: 0.1 log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with degree: 1 C: 0.6
# accuracy: 0.5013774104683195
# log_return: 0.2578317011364651
# simple_return: 1.2941210012017605
#  up%: 1.0
# 1 0.6
# Current Best Ret: degree: 1 C: 0.1 log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with degree: 1 C: 0.7
# accuracy: 0.4986225895316804
# log_return: 0.25416663937129247
# simple_return: 1.2893866489470494
#  up%: 0.9972451790633609
# 1 0.7
# Current Best Ret: degree: 1 C: 0.1 log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with degree: 1 C: 0.8
# accuracy: 0.49586776859504134
# log_return: 0.2370924149640625
# simple_return: 1.2675582537131076
#  up%: 0.9889807162534435
# 1 0.8
# Current Best Ret: degree: 1 C: 0.1 log ret: 0.2578317011364651 simple ret: 1.2941210012017605
# ---
# ---
# SVC Poly with degree: 1 C: 0.9
# accuracy: 0.5068870523415978
# log_return: 0.3546950959133549
# simple_return: 1.4257458722584717
#  up%: 0.9724517906336089
# 1 0.9
# Current Best Ret: degree: 1 C: 0.9 log ret: 0.3546950959133549 simple ret: 1.4257458722584717
# ---
# ---
# SVC Poly with degree: 1 C: 1.0
# accuracy: 0.509641873278237
# log_return: 0.39131254123401016
# simple_return: 1.4789206648782949
#  up%: 0.9146005509641874
# 1 1.0
# Current Best Ret: degree: 1 C: 1.0 log ret: 0.39131254123401016 simple ret: 1.4789206648782949
# ---
# ---
# SVC Poly with degree: 1 C: 1.1
# accuracy: 0.5316804407713499
# log_return: 0.4328908116711673
# simple_return: 1.5417078750036872
#  up%: 0.8539944903581267
# 1 1.1
# Current Best Ret: degree: 1 C: 1.1 log ret: 0.4328908116711673 simple ret: 1.5417078750036872
# ---
# ---
# SVC Poly with degree: 1 C: 1.2
# accuracy: 0.5344352617079889
# log_return: 0.4448529412234733
# simple_return: 1.5602607289266603
#  up%: 0.8622589531680441
# 1 1.2
# Current Best Ret: degree: 1 C: 1.2 log ret: 0.4448529412234733 simple ret: 1.5602607289266603
# ---
# ---
# SVC Poly with degree: 1 C: 1.3
# accuracy: 0.5344352617079889
# log_return: 0.441586743800555
# simple_return: 1.5551729227675204
#  up%: 0.8567493112947658
# 1 1.3
# Current Best Ret: degree: 1 C: 1.2 log ret: 0.4448529412234733 simple ret: 1.5602607289266603
# ---
# ---
# SVC Poly with degree: 1 C: 1.4
# accuracy: 0.5371900826446281
# log_return: 0.44567626016351175
# simple_return: 1.5615458500958896
#  up%: 0.8539944903581267
# 1 1.4
# Current Best Ret: degree: 1 C: 1.4 log ret: 0.44567626016351175 simple ret: 1.5615458500958896
# ---
# ---
# SVC Poly with degree: 1 C: 1.5
# accuracy: 0.5426997245179064
# log_return: 0.5118625513767472
# simple_return: 1.6683957756767673
#  up%: 0.837465564738292
# 1 1.5
# Current Best Ret: degree: 1 C: 1.5 log ret: 0.5118625513767472 simple ret: 1.6683957756767673
# ---
# ---
# SVC Poly with degree: 1 C: 1.6
# accuracy: 0.5371900826446281
# log_return: 0.512685089230396
# simple_return: 1.6697686589039367
#  up%: 0.8264462809917356
# 1 1.6
# Current Best Ret: degree: 1 C: 1.6 log ret: 0.512685089230396 simple ret: 1.6697686589039367
# ---
# ---
# SVC Poly with degree: 1 C: 1.7
# accuracy: 0.5344352617079889
# log_return: 0.47992649885950023
# simple_return: 1.6159556232464471
#  up%: 0.8402203856749312
# 1 1.7
# Current Best Ret: degree: 1 C: 1.6 log ret: 0.512685089230396 simple ret: 1.6697686589039367
# ---
# ---
# SVC Poly with degree: 1 C: 1.8
# accuracy: 0.5426997245179064
# log_return: 0.5317210258414165
# simple_return: 1.701858732527764
#  up%: 0.8319559228650137
# 1 1.8
# Current Best Ret: degree: 1 C: 1.8 log ret: 0.5317210258414165 simple ret: 1.701858732527764
# ---
# ---
# SVC Poly with degree: 1 C: 1.9
# accuracy: 0.5399449035812672
# log_return: 0.5249147365500512
# simple_return: 1.6903147201702036
#  up%: 0.8292011019283747
# 1 1.9
# Current Best Ret: degree: 1 C: 1.8 log ret: 0.5317210258414165 simple ret: 1.701858732527764
# ---
# ---
# SVC Poly with degree: 1 C: 2.0
# accuracy: 0.5399449035812672
# log_return: 0.5249147365500512
# simple_return: 1.6903147201702036
#  up%: 0.8292011019283747
# 1 2.0
# Current Best Ret: degree: 1 C: 1.8 log ret: 0.5317210258414165 simple ret: 1.701858732527764
# ---
# ---
# SVC Poly with degree: 1 C: 2.1
# accuracy: 0.5344352617079889
# log_return: 0.48858429789138347
# simple_return: 1.6300069814234723
#  up%: 0.8402203856749312
# 1 2.1
# Current Best Ret: degree: 1 C: 1.8 log ret: 0.5317210258414165 simple ret: 1.701858732527764
# ---
# ---
# SVC Poly with degree: 1 C: 2.2
# accuracy: 0.5454545454545454
# log_return: 0.5269294737106365
# simple_return: 1.6937236929889914
#  up%: 0.8236914600550964
# 1 2.2
# Current Best Ret: degree: 1 C: 1.8 log ret: 0.5317210258414165 simple ret: 1.701858732527764
# ---
# ---
# SVC Poly with degree: 1 C: 2.3
# accuracy: 0.5537190082644629
# log_return: 0.5977849059084708
# simple_return: 1.8180871027450243
#  up%: 0.8154269972451791
# 1 2.3
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 2.4
# accuracy: 0.5509641873278237
# log_return: 0.5509269550557363
# simple_return: 1.734860410390395
#  up%: 0.8181818181818182
# 1 2.4
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 2.5
# accuracy: 0.5509641873278237
# log_return: 0.5509269550557363
# simple_return: 1.734860410390395
#  up%: 0.8181818181818182
# 1 2.5
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 2.6
# accuracy: 0.5509641873278237
# log_return: 0.5832176773291591
# simple_return: 1.7917945818698522
#  up%: 0.8126721763085399
# 1 2.6
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 2.7
# accuracy: 0.5509641873278237
# log_return: 0.5832176773291591
# simple_return: 1.7917945818698522
#  up%: 0.8126721763085399
# 1 2.7
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 2.8
# accuracy: 0.5482093663911846
# log_return: 0.5363597264764245
# simple_return: 1.7097714839650167
#  up%: 0.8154269972451791
# 1 2.8
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 2.9
# accuracy: 0.5371900826446281
# log_return: 0.5006702540726806
# simple_return: 1.6498267032654859
#  up%: 0.8209366391184573
# 1 2.9
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 3.0
# accuracy: 0.5344352617079889
# log_return: 0.4880210228841736
# simple_return: 1.62908909776399
#  up%: 0.8181818181818182
# 1 3.0
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 3.1
# accuracy: 0.5316804407713499
# log_return: 0.4873363649211913
# simple_return: 1.6279741106767471
#  up%: 0.8209366391184573
# 1 3.1
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 3.2
# accuracy: 0.5316804407713499
# log_return: 0.5689597225816883
# simple_return: 1.7664285196079559
#  up%: 0.8264462809917356
# 1 3.2
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 3.3
# accuracy: 0.5316804407713499
# log_return: 0.5689597225816883
# simple_return: 1.7664285196079559
#  up%: 0.8264462809917356
# 1 3.3
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 3.4
# accuracy: 0.5316804407713499
# log_return: 0.5689597225816883
# simple_return: 1.7664285196079559
#  up%: 0.8264462809917356
# 1 3.4
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 3.5
# accuracy: 0.5316804407713499
# log_return: 0.5689597225816883
# simple_return: 1.7664285196079559
#  up%: 0.8264462809917356
# 1 3.5
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 3.6
# accuracy: 0.5289256198347108
# log_return: 0.5537658023874391
# simple_return: 1.7397924115241663
#  up%: 0.8292011019283747
# 1 3.6
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 3.7
# accuracy: 0.5289256198347108
# log_return: 0.5537658023874391
# simple_return: 1.7397924115241663
#  up%: 0.8292011019283747
# 1 3.7
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 3.8
# accuracy: 0.5316804407713499
# log_return: 0.5738816370392377
# simple_return: 1.7751441609024194
#  up%: 0.8319559228650137
# 1 3.8
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 3.9
# accuracy: 0.5344352617079889
# log_return: 0.5825868819819697
# simple_return: 1.79066468258956
#  up%: 0.8347107438016529
# 1 3.9
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 4.0
# accuracy: 0.5261707988980716
# log_return: 0.5334801780470277
# simple_return: 1.7048551959155758
#  up%: 0.8429752066115702
# 1 4.0
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 4.1
# accuracy: 0.5261707988980716
# log_return: 0.5384157527226052
# simple_return: 1.7132904352995495
#  up%: 0.8484848484848485
# 1 4.1
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 4.2
# accuracy: 0.5234159779614325
# log_return: 0.4510301090323618
# simple_return: 1.5699285504111273
#  up%: 0.8732782369146006
# 1 4.2
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 4.3
# accuracy: 0.5234159779614325
# log_return: 0.4510301090323618
# simple_return: 1.5699285504111273
#  up%: 0.8732782369146006
# 1 4.3
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 4.4
# accuracy: 0.5234159779614325
# log_return: 0.4510301090323618
# simple_return: 1.5699285504111273
#  up%: 0.8732782369146006
# 1 4.4
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 4.5
# accuracy: 0.5206611570247934
# log_return: 0.4228331037401846
# simple_return: 1.5262795443611163
#  up%: 0.8760330578512396
# 1 4.5
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 4.6
# accuracy: 0.5234159779614325
# log_return: 0.4277468225195662
# simple_return: 1.5337977087667058
#  up%: 0.8842975206611571
# 1 4.6
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 4.7
# accuracy: 0.5234159779614325
# log_return: 0.4277468225195662
# simple_return: 1.5337977087667058
#  up%: 0.8842975206611571
# 1 4.7
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 4.8
# accuracy: 0.5234159779614325
# log_return: 0.4277468225195662
# simple_return: 1.5337977087667058
#  up%: 0.8842975206611571
# 1 4.8
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 4.9
# accuracy: 0.5206611570247934
# log_return: 0.411452757177576
# simple_return: 1.5090084163077935
#  up%: 0.8815426997245179
# 1 4.9
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 5.0
# accuracy: 0.5206611570247934
# log_return: 0.411452757177576
# simple_return: 1.5090084163077935
#  up%: 0.8815426997245179
# 1 5.0
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 5.1
# accuracy: 0.5179063360881543
# log_return: 0.43085326953461467
# simple_return: 1.5385697783338799
#  up%: 0.8732782369146006
# 1 5.1
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 5.2
# accuracy: 0.5206611570247934
# log_return: 0.4399570252326305
# simple_return: 1.5526404927136006
#  up%: 0.8650137741046832
# 1 5.2
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 5.3
# accuracy: 0.5206611570247934
# log_return: 0.4399570252326305
# simple_return: 1.5526404927136006
#  up%: 0.8650137741046832
# 1 5.3
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 5.4
# accuracy: 0.5151515151515151
# log_return: 0.39164418528865474
# simple_return: 1.4794112214646842
#  up%: 0.8650137741046832
# 1 5.4
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 5.5
# accuracy: 0.5151515151515151
# log_return: 0.39164418528865474
# simple_return: 1.4794112214646842
#  up%: 0.8650137741046832
# 1 5.5
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 5.6
# accuracy: 0.5151515151515151
# log_return: 0.39164418528865474
# simple_return: 1.4794112214646842
#  up%: 0.8650137741046832
# 1 5.6
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 5.7
# accuracy: 0.5151515151515151
# log_return: 0.39164418528865474
# simple_return: 1.4794112214646842
#  up%: 0.8650137741046832
# 1 5.7
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 5.8
# accuracy: 0.5151515151515151
# log_return: 0.39164418528865474
# simple_return: 1.4794112214646842
#  up%: 0.8650137741046832
# 1 5.8
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 5.9
# accuracy: 0.5151515151515151
# log_return: 0.39164418528865474
# simple_return: 1.4794112214646842
#  up%: 0.8650137741046832
# 1 5.9
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 6.0
# accuracy: 0.5151515151515151
# log_return: 0.39164418528865474
# simple_return: 1.4794112214646842
#  up%: 0.8650137741046832
# 1 6.0
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 6.1
# accuracy: 0.5151515151515151
# log_return: 0.39164418528865474
# simple_return: 1.4794112214646842
#  up%: 0.8650137741046832
# 1 6.1
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 6.2
# accuracy: 0.512396694214876
# log_return: 0.37627307571794677
# simple_return: 1.4568449084266202
#  up%: 0.8622589531680441
# 1 6.2
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 6.3
# accuracy: 0.5151515151515151
# log_return: 0.391466995912196
# simple_return: 1.4791491087353081
#  up%: 0.859504132231405
# 1 6.3
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 6.4
# accuracy: 0.5206611570247934
# log_return: 0.47198352166240287
# simple_return: 1.6031709659165116
#  up%: 0.8539944903581267
# 1 6.4
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 6.5
# accuracy: 0.5234159779614325
# log_return: 0.5004306060416294
# simple_return: 1.6494313729164343
#  up%: 0.8457300275482094
# 1 6.5
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 6.6
# accuracy: 0.5261707988980716
# log_return: 0.5137523029724224
# simple_return: 1.6715516101885561
#  up%: 0.8429752066115702
# 1 6.6
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 6.7
# accuracy: 0.5234159779614325
# log_return: 0.5069460136810572
# simple_return: 1.6602131764657668
#  up%: 0.8402203856749312
# 1 6.7
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 6.8
# accuracy: 0.5261707988980716
# log_return: 0.5137523029724224
# simple_return: 1.6715516101885561
#  up%: 0.8429752066115702
# 1 6.8
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 6.9
# accuracy: 0.5234159779614325
# log_return: 0.5019289024621687
# simple_return: 1.6519045623611763
#  up%: 0.8457300275482094
# 1 6.9
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 7.0
# accuracy: 0.5206611570247934
# log_return: 0.4511182870551306
# simple_return: 1.570066989710153
#  up%: 0.8484848484848485
# 1 7.0
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 7.1
# accuracy: 0.5206611570247934
# log_return: 0.4511182870551306
# simple_return: 1.570066989710153
#  up%: 0.8484848484848485
# 1 7.1
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 7.2
# accuracy: 0.5206611570247934
# log_return: 0.4511182870551306
# simple_return: 1.570066989710153
#  up%: 0.8484848484848485
# 1 7.2
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 7.3
# accuracy: 0.5206611570247934
# log_return: 0.4511182870551306
# simple_return: 1.570066989710153
#  up%: 0.8484848484848485
# 1 7.3
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 7.4
# accuracy: 0.5234159779614325
# log_return: 0.4545772764834485
# simple_return: 1.575507238286265
#  up%: 0.8512396694214877
# 1 7.4
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 7.5
# accuracy: 0.5234159779614325
# log_return: 0.4545772764834485
# simple_return: 1.575507238286265
#  up%: 0.8512396694214877
# 1 7.5
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 7.6
# accuracy: 0.5234159779614325
# log_return: 0.4545772764834485
# simple_return: 1.575507238286265
#  up%: 0.8512396694214877
# 1 7.6
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 7.7
# accuracy: 0.5234159779614325
# log_return: 0.4545772764834485
# simple_return: 1.575507238286265
#  up%: 0.8512396694214877
# 1 7.7
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 7.8
# accuracy: 0.5234159779614325
# log_return: 0.4545772764834485
# simple_return: 1.575507238286265
#  up%: 0.8512396694214877
# 1 7.8
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 7.9
# accuracy: 0.5234159779614325
# log_return: 0.4545772764834485
# simple_return: 1.575507238286265
#  up%: 0.8512396694214877
# 1 7.9
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 8.0
# accuracy: 0.5234159779614325
# log_return: 0.4545772764834485
# simple_return: 1.575507238286265
#  up%: 0.8512396694214877
# 1 8.0
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 8.1
# accuracy: 0.5206611570247934
# log_return: 0.42487136614027965
# simple_return: 1.5293936751981774
#  up%: 0.8539944903581267
# 1 8.1
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 8.2
# accuracy: 0.5206611570247934
# log_return: 0.42487136614027965
# simple_return: 1.5293936751981774
#  up%: 0.8539944903581267
# 1 8.2
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 8.3
# accuracy: 0.5206611570247934
# log_return: 0.42487136614027965
# simple_return: 1.5293936751981774
#  up%: 0.8539944903581267
# 1 8.3
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 8.4
# accuracy: 0.5151515151515151
# log_return: 0.40122204675701756
# simple_return: 1.4936488915731803
#  up%: 0.859504132231405
# 1 8.4
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 8.5
# accuracy: 0.512396694214876
# log_return: 0.3860281265627684
# simple_return: 1.47112604795197
#  up%: 0.8622589531680441
# 1 8.5
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 8.6
# accuracy: 0.5206611570247934
# log_return: 0.4341961094533697
# simple_return: 1.5437215768280836
#  up%: 0.8539944903581267
# 1 8.6
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 8.7
# accuracy: 0.5206611570247934
# log_return: 0.4341961094533697
# simple_return: 1.5437215768280836
#  up%: 0.8539944903581267
# 1 8.7
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 8.8
# accuracy: 0.5206611570247934
# log_return: 0.4341961094533697
# simple_return: 1.5437215768280836
#  up%: 0.8539944903581267
# 1 8.8
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 8.9
# accuracy: 0.5206611570247934
# log_return: 0.4341961094533697
# simple_return: 1.5437215768280836
#  up%: 0.8539944903581267
# 1 8.9
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 9.0
# accuracy: 0.5206611570247934
# log_return: 0.4341961094533697
# simple_return: 1.5437215768280836
#  up%: 0.8539944903581267
# 1 9.0
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 9.1
# accuracy: 0.5179063360881543
# log_return: 0.43360559895275586
# simple_return: 1.542810262123875
#  up%: 0.8512396694214877
# 1 9.1
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 9.2
# accuracy: 0.5179063360881543
# log_return: 0.43360559895275586
# simple_return: 1.542810262123875
#  up%: 0.8512396694214877
# 1 9.2
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 9.3
# accuracy: 0.5179063360881543
# log_return: 0.43360559895275586
# simple_return: 1.542810262123875
#  up%: 0.8512396694214877
# 1 9.3
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 9.4
# accuracy: 0.5179063360881543
# log_return: 0.43360559895275586
# simple_return: 1.542810262123875
#  up%: 0.8512396694214877
# 1 9.4
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 9.5
# accuracy: 0.5179063360881543
# log_return: 0.43360559895275586
# simple_return: 1.542810262123875
#  up%: 0.8512396694214877
# 1 9.5
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 9.6
# accuracy: 0.5179063360881543
# log_return: 0.43360559895275586
# simple_return: 1.542810262123875
#  up%: 0.8512396694214877
# 1 9.6
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 9.7
# accuracy: 0.5179063360881543
# log_return: 0.43360559895275586
# simple_return: 1.542810262123875
#  up%: 0.8512396694214877
# 1 9.7
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 9.8
# accuracy: 0.5179063360881543
# log_return: 0.43360559895275586
# simple_return: 1.542810262123875
#  up%: 0.8512396694214877
# 1 9.8
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 9.9
# accuracy: 0.5179063360881543
# log_return: 0.43360559895275586
# simple_return: 1.542810262123875
#  up%: 0.8512396694214877
# 1 9.9
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 1 C: 10.0
# accuracy: 0.5179063360881543
# log_return: 0.43360559895275586
# simple_return: 1.542810262123875
#  up%: 0.8512396694214877
# 1 10.0
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 0.1
# accuracy: 0.5261707988980716
# log_return: 0.33197785876177366
# simple_return: 1.3937219894402992
#  up%: 0.4738292011019284
# 2 0.1
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 0.2
# accuracy: 0.5234159779614325
# log_return: 0.27830640459602357
# simple_return: 1.3208908622413529
#  up%: 0.41597796143250687
# 2 0.2
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 0.3
# accuracy: 0.5179063360881543
# log_return: 0.05915770335929443
# simple_return: 1.060942541750699
#  up%: 0.39944903581267216
# 2 0.3
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 0.4
# accuracy: 0.5234159779614325
# log_return: 0.11072448518884259
# simple_return: 1.1170870904136494
#  up%: 0.371900826446281
# 2 0.4
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 0.5
# accuracy: 0.5289256198347108
# log_return: 0.13915346764137285
# simple_return: 1.1493004669018372
#  up%: 0.3443526170798898
# 2 0.5
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 0.6
# accuracy: 0.5234159779614325
# log_return: 0.1029062881846815
# simple_return: 1.1083875352009784
#  up%: 0.3443526170798898
# 2 0.6
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 0.7
# accuracy: 0.5289256198347108
# log_return: 0.12027060810866178
# simple_return: 1.1278020026562194
#  up%: 0.3608815426997245
# 2 0.7
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 0.8
# accuracy: 0.5289256198347108
# log_return: 0.08600429318047814
# simple_return: 1.0898110070504257
#  up%: 0.349862258953168
# 2 0.8
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 0.9
# accuracy: 0.512396694214876
# log_return: -0.021044313768261498
# simple_return: 0.9791755726486232
#  up%: 0.3333333333333333
# 2 0.9
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 1.0
# accuracy: 0.512396694214876
# log_return: -0.030575638105697994
# simple_return: 0.9698870688720885
#  up%: 0.2837465564738292
# 2 1.0
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 1.1
# accuracy: 0.5068870523415978
# log_return: -0.05309927598321159
# simple_return: 0.9482858657974305
#  up%: 0.2837465564738292
# 2 1.1
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 1.2
# accuracy: 0.509641873278237
# log_return: -0.02086280440623372
# simple_return: 0.979353318312891
#  up%: 0.2699724517906336
# 2 1.2
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 1.3
# accuracy: 0.509641873278237
# log_return: 0.0042424208445046435
# simple_return: 1.004251432651268
#  up%: 0.2534435261707989
# 2 1.3
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 1.4
# accuracy: 0.5068870523415978
# log_return: -0.02517845120212589
# simple_return: 0.9751358823304521
#  up%: 0.25068870523415976
# 2 1.4
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 1.5
# accuracy: 0.5013774104683195
# log_return: -0.12178815901524956
# simple_return: 0.8853358990672894
#  up%: 0.26721763085399447
# 2 1.5
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 1.6
# accuracy: 0.5041322314049587
# log_return: -0.07983936353614055
# simple_return: 0.923264644442969
#  up%: 0.25895316804407714
# 2 1.6
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 1.7
# accuracy: 0.4986225895316804
# log_return: -0.18972298234499582
# simple_return: 0.8271882479562798
#  up%: 0.2644628099173554
# 2 1.7
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 1.8
# accuracy: 0.4986225895316804
# log_return: -0.18972298234499582
# simple_return: 0.8271882479562798
#  up%: 0.2644628099173554
# 2 1.8
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 1.9
# accuracy: 0.5013774104683195
# log_return: -0.15070465929539853
# simple_return: 0.8601016841886638
#  up%: 0.256198347107438
# 2 1.9
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 2.0
# accuracy: 0.509641873278237
# log_return: -0.09523480456314674
# simple_return: 0.9091594346199664
#  up%: 0.24793388429752067
# 2 2.0
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 2.1
# accuracy: 0.5151515151515151
# log_return: -0.0476500774816805
# simple_return: 0.953467368412981
#  up%: 0.2369146005509642
# 2 2.1
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 2.2
# accuracy: 0.5179063360881543
# log_return: 0.01466321677307654
# simple_return: 1.0147712491242185
#  up%: 0.2231404958677686
# 2 2.2
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 2.3
# accuracy: 0.512396694214876
# log_return: -0.0432007710057184
# simple_return: 0.9577190885387894
#  up%: 0.21763085399449036
# 2 2.3
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 2.4
# accuracy: 0.5068870523415978
# log_return: -0.07358939983096802
# simple_return: 0.9290530848900098
#  up%: 0.22865013774104684
# 2 2.4
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 2.5
# accuracy: 0.5041322314049587
# log_return: -0.07419906299679277
# simple_return: 0.9284868480694616
#  up%: 0.22589531680440772
# 2 2.5
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 2.6
# accuracy: 0.5041322314049587
# log_return: -0.07419906299679277
# simple_return: 0.9284868480694616
#  up%: 0.22589531680440772
# 2 2.6
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 2.7
# accuracy: 0.509641873278237
# log_return: -0.037433576138356114
# simple_return: 0.9632583989384769
#  up%: 0.22589531680440772
# 2 2.7
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 2.8
# accuracy: 0.5151515151515151
# log_return: -0.028720611426549164
# simple_return: 0.9716879050437709
#  up%: 0.22038567493112948
# 2 2.8
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 2.9
# accuracy: 0.5206611570247934
# log_return: -0.025616208928493686
# simple_return: 0.9747091024836066
#  up%: 0.209366391184573
# 2 2.9
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 3.0
# accuracy: 0.5234159779614325
# log_return: -0.016284025184035572
# simple_return: 0.9838478428032598
#  up%: 0.2066115702479339
# 2 3.0
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 3.1
# accuracy: 0.5261707988980716
# log_return: 0.003321958730104893
# simple_return: 1.0033274825499474
#  up%: 0.20385674931129477
# 2 3.1
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 3.2
# accuracy: 0.5261707988980716
# log_return: 0.003321958730104893
# simple_return: 1.0033274825499474
#  up%: 0.20385674931129477
# 2 3.2
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 3.3
# accuracy: 0.5289256198347108
# log_return: 0.010688909466396071
# simple_return: 1.010746239943869
#  up%: 0.2066115702479339
# 2 3.3
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 3.4
# accuracy: 0.5316804407713499
# log_return: 0.01618018571466047
# simple_return: 1.0163117937757224
#  up%: 0.209366391184573
# 2 3.4
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 3.5
# accuracy: 0.5261707988980716
# log_return: -0.025695183901621926
# simple_return: 0.974632127898003
#  up%: 0.21487603305785125
# 2 3.5
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 3.6
# accuracy: 0.5289256198347108
# log_return: 0.008419377612846779
# simple_return: 1.0084549202514814
#  up%: 0.21763085399449036
# 2 3.6
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 3.7
# accuracy: 0.5289256198347108
# log_return: 0.008419377612846779
# simple_return: 1.0084549202514814
#  up%: 0.21763085399449036
# 2 3.7
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 3.8
# accuracy: 0.5261707988980716
# log_return: -0.011186606301293672
# simple_return: 0.9888757311144036
#  up%: 0.22038567493112948
# 2 3.8
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 3.9
# accuracy: 0.5234159779614325
# log_return: -0.014856638192752944
# simple_return: 0.9852531771548583
#  up%: 0.21763085399449036
# 2 3.9
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 4.0
# accuracy: 0.5234159779614325
# log_return: 0.003585333137757968
# simple_return: 1.0035917681328477
#  up%: 0.2231404958677686
# 2 4.0
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 4.1
# accuracy: 0.5179063360881543
# log_return: -0.02150425704290225
# simple_return: 0.9787253109846408
#  up%: 0.2231404958677686
# 2 4.1
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 4.2
# accuracy: 0.5179063360881543
# log_return: -0.02150425704290225
# simple_return: 0.9787253109846408
#  up%: 0.2231404958677686
# 2 4.2
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 4.3
# accuracy: 0.5151515151515151
# log_return: -0.10338850259586684
# simple_return: 0.9017765628826384
#  up%: 0.22038567493112948
# 2 4.3
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 4.4
# accuracy: 0.5151515151515151
# log_return: -0.11694794391339002
# simple_return: 0.8896315026926096
#  up%: 0.22038567493112948
# 2 4.4
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 4.5
# accuracy: 0.5151515151515151
# log_return: -0.03639658744674633
# simple_return: 0.9642578051021603
#  up%: 0.22038567493112948
# 2 4.5
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 4.6
# accuracy: 0.512396694214876
# log_return: -0.044441899530316575
# simple_return: 0.9565311733896287
#  up%: 0.2231404958677686
# 2 4.6
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 4.7
# accuracy: 0.512396694214876
# log_return: -0.02753706971621049
# simple_return: 0.9728386190334997
#  up%: 0.22865013774104684
# 2 4.7
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 4.8
# accuracy: 0.5151515151515151
# log_return: -0.026512217016357226
# simple_return: 0.9738361463907298
#  up%: 0.22589531680440772
# 2 4.8
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 4.9
# accuracy: 0.5151515151515151
# log_return: -0.026512217016357226
# simple_return: 0.9738361463907298
#  up%: 0.22589531680440772
# 2 4.9
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 5.0
# accuracy: 0.5179063360881543
# log_return: -0.024512307754672183
# simple_return: 0.9757856791137495
#  up%: 0.22865013774104684
# 2 5.0
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 5.1
# accuracy: 0.5151515151515151
# log_return: -0.026512217016357226
# simple_return: 0.9738361463907298
#  up%: 0.22589531680440772
# 2 5.1
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 5.2
# accuracy: 0.5179063360881543
# log_return: -0.01628935478223556
# simple_return: 0.9838425993035406
#  up%: 0.2231404958677686
# 2 5.2
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 5.3
# accuracy: 0.5179063360881543
# log_return: -0.0961736910735151
# simple_return: 0.9083062376812507
#  up%: 0.2231404958677686
# 2 5.3
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 5.4
# accuracy: 0.5179063360881543
# log_return: -0.07257267923022058
# simple_return: 0.9299981526541266
#  up%: 0.21763085399449036
# 2 5.4
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 5.5
# accuracy: 0.5206611570247934
# log_return: -0.05695157529016884
# simple_return: 0.9446398121677727
#  up%: 0.209366391184573
# 2 5.5
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 5.6
# accuracy: 0.5234159779614325
# log_return: -0.037345591376028386
# simple_return: 0.963343154728322
#  up%: 0.2066115702479339
# 2 5.6
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 5.7
# accuracy: 0.5289256198347108
# log_return: -0.02363254561709814
# simple_return: 0.9766445161393758
#  up%: 0.20110192837465565
# 2 5.7
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 5.8
# accuracy: 0.5371900826446281
# log_return: 0.04165332972632855
# simple_return: 1.0425330008968376
#  up%: 0.1928374655647383
# 2 5.8
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 5.9
# accuracy: 0.5399449035812672
# log_return: 0.04515668800629077
# simple_return: 1.046191772769865
#  up%: 0.19008264462809918
# 2 5.9
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 6.0
# accuracy: 0.5399449035812672
# log_return: 0.04515668800629077
# simple_return: 1.046191772769865
#  up%: 0.19008264462809918
# 2 6.0
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 6.1
# accuracy: 0.5426997245179064
# log_return: 0.06278989819296643
# simple_return: 1.0648030986728145
#  up%: 0.1928374655647383
# 2 6.1
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 6.2
# accuracy: 0.5454545454545454
# log_return: 0.14467414374593102
# simple_return: 1.155662928912902
#  up%: 0.19559228650137742
# 2 6.2
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 6.3
# accuracy: 0.5454545454545454
# log_return: 0.14467414374593102
# simple_return: 1.155662928912902
#  up%: 0.19559228650137742
# 2 6.3
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 6.4
# accuracy: 0.5426997245179064
# log_return: 0.10877355223497304
# simple_return: 1.1149098529093893
#  up%: 0.1928374655647383
# 2 6.4
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 6.5
# accuracy: 0.5426997245179064
# log_return: 0.10877355223497304
# simple_return: 1.1149098529093893
#  up%: 0.1928374655647383
# 2 6.5
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 6.6
# accuracy: 0.5399449035812672
# log_return: 0.10774869953511976
# simple_return: 1.1137678198443357
#  up%: 0.19559228650137742
# 2 6.6
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 6.7
# accuracy: 0.5371900826446281
# log_return: 0.0258644539821552
# simple_return: 1.0262018414728384
#  up%: 0.1928374655647383
# 2 6.7
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 6.8
# accuracy: 0.5344352617079889
# log_return: 0.017989754088789472
# simple_return: 1.0181525444357824
#  up%: 0.19559228650137742
# 2 6.8
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 6.9
# accuracy: 0.5344352617079889
# log_return: 0.017989754088789472
# simple_return: 1.0181525444357824
#  up%: 0.19559228650137742
# 2 6.9
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 7.0
# accuracy: 0.5344352617079889
# log_return: 0.017989754088789472
# simple_return: 1.0181525444357824
#  up%: 0.19559228650137742
# 2 7.0
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 7.1
# accuracy: 0.5316804407713499
# log_return: 0.016109492423015653
# simple_return: 1.0162399498891534
#  up%: 0.1928374655647383
# 2 7.1
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 7.2
# accuracy: 0.5316804407713499
# log_return: 0.016109492423015653
# simple_return: 1.0162399498891534
#  up%: 0.1928374655647383
# 2 7.2
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 7.3
# accuracy: 0.5316804407713499
# log_return: 0.016109492423015653
# simple_return: 1.0162399498891534
#  up%: 0.1928374655647383
# 2 7.3
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 7.4
# accuracy: 0.5316804407713499
# log_return: 0.016109492423015653
# simple_return: 1.0162399498891534
#  up%: 0.1928374655647383
# 2 7.4
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 7.5
# accuracy: 0.5316804407713499
# log_return: 0.016109492423015653
# simple_return: 1.0162399498891534
#  up%: 0.1928374655647383
# 2 7.5
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 7.6
# accuracy: 0.5316804407713499
# log_return: 0.016109492423015653
# simple_return: 1.0162399498891534
#  up%: 0.1928374655647383
# 2 7.6
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 7.7
# accuracy: 0.5289256198347108
# log_return: 0.010801042883335749
# simple_return: 1.010859584728163
#  up%: 0.19008264462809918
# 2 7.7
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 7.8
# accuracy: 0.5289256198347108
# log_return: 0.08381664822888288
# simple_return: 1.0874294934055952
#  up%: 0.19559228650137742
# 2 7.8
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 7.9
# accuracy: 0.5289256198347108
# log_return: 0.08381664822888288
# simple_return: 1.0874294934055952
#  up%: 0.19559228650137742
# 2 7.9
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 8.0
# accuracy: 0.5289256198347108
# log_return: 0.08381664822888288
# simple_return: 1.0874294934055952
#  up%: 0.19559228650137742
# 2 8.0
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 8.1
# accuracy: 0.5289256198347108
# log_return: 0.08381664822888288
# simple_return: 1.0874294934055952
#  up%: 0.19559228650137742
# 2 8.1
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 8.2
# accuracy: 0.5289256198347108
# log_return: 0.08381664822888288
# simple_return: 1.0874294934055952
#  up%: 0.19559228650137742
# 2 8.2
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 8.3
# accuracy: 0.5289256198347108
# log_return: 0.08381664822888288
# simple_return: 1.0874294934055952
#  up%: 0.19559228650137742
# 2 8.3
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 8.4
# accuracy: 0.5289256198347108
# log_return: 0.08381664822888288
# simple_return: 1.0874294934055952
#  up%: 0.19559228650137742
# 2 8.4
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 8.5
# accuracy: 0.5316804407713499
# log_return: 0.09121176209724913
# simple_return: 1.0955009662794801
#  up%: 0.19834710743801653
# 2 8.5
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 2 C: 8.6
# accuracy: 0.5316804407713499
# log_return: 0.09121176209724913
# simple_return: 1.0955009662794801
#  up%: 0.19834710743801653
# 2 8.6
# ...
#  up%: 0.2809917355371901
# 4 2.8
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 2.9
# accuracy: 0.5344352617079889
# log_return: -0.07985281426237073
# simple_return: 0.9232522259465177
#  up%: 0.27823691460055094
# 4 2.9
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 3.0
# accuracy: 0.5344352617079889
# log_return: -0.07122099397067905
# simple_return: 0.9312560674093632
#  up%: 0.27823691460055094
# 4 3.0
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 3.1
# accuracy: 0.5344352617079889
# log_return: -0.07122099397067905
# simple_return: 0.9312560674093632
#  up%: 0.27823691460055094
# 4 3.1
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 3.2
# accuracy: 0.5399449035812672
# log_return: -0.010628393262745811
# simple_return: 0.9894278885374139
#  up%: 0.2837465564738292
# 4 3.2
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 3.3
# accuracy: 0.5399449035812672
# log_return: -0.02692823165412872
# simple_return: 0.9734311005573798
#  up%: 0.2892561983471074
# 4 3.3
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 3.4
# accuracy: 0.5426997245179064
# log_return: -0.004031550907353965
# simple_return: 0.9959765648839336
#  up%: 0.2809917355371901
# 4 3.4
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 3.5
# accuracy: 0.5426997245179064
# log_return: -0.004031550907353965
# simple_return: 0.9959765648839336
#  up%: 0.2809917355371901
# 4 3.5
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 3.6
# accuracy: 0.5399449035812672
# log_return: -0.020058485067411896
# simple_return: 0.9801413479976235
#  up%: 0.27823691460055094
# 4 3.6
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 3.7
# accuracy: 0.5399449035812672
# log_return: -0.020058485067411896
# simple_return: 0.9801413479976235
#  up%: 0.27823691460055094
# 4 3.7
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 3.8
# accuracy: 0.5399449035812672
# log_return: -0.020058485067411896
# simple_return: 0.9801413479976235
#  up%: 0.27823691460055094
# 4 3.8
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 3.9
# accuracy: 0.5399449035812672
# log_return: -0.020058485067411896
# simple_return: 0.9801413479976235
#  up%: 0.27823691460055094
# 4 3.9
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 4.0
# accuracy: 0.5344352617079889
# log_return: -0.08747246306853332
# simple_return: 0.9162441018545343
#  up%: 0.27823691460055094
# 4 4.0
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 4.1
# accuracy: 0.5316804407713499
# log_return: -0.10994301160627176
# simple_return: 0.8958851888996633
#  up%: 0.27548209366391185
# 4 4.1
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 4.2
# accuracy: 0.5344352617079889
# log_return: -0.09391607744621383
# simple_return: 0.9103591587004899
#  up%: 0.27823691460055094
# 4 4.2
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 4.3
# accuracy: 0.5344352617079889
# log_return: -0.09391607744621383
# simple_return: 0.9103591587004899
#  up%: 0.27823691460055094
# 4 4.3
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 4.4
# accuracy: 0.5289256198347108
# log_return: -0.09938772588048983
# simple_return: 0.9053915962065506
#  up%: 0.2837465564738292
# 4 4.4
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 4.5
# accuracy: 0.5289256198347108
# log_return: -0.09938772588048983
# simple_return: 0.9053915962065506
#  up%: 0.2837465564738292
# 4 4.5
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 4.6
# accuracy: 0.5316804407713499
# log_return: -0.09720938865347964
# simple_return: 0.9073659940970675
#  up%: 0.2809917355371901
# 4 4.6
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 4.7
# accuracy: 0.5316804407713499
# log_return: -0.09720938865347964
# simple_return: 0.9073659940970675
#  up%: 0.2809917355371901
# 4 4.7
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 4.8
# accuracy: 0.5316804407713499
# log_return: -0.09720938865347964
# simple_return: 0.9073659940970675
#  up%: 0.2809917355371901
# 4 4.8
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 4.9
# accuracy: 0.5289256198347108
# log_return: -0.10383787976317585
# simple_return: 0.9013714161239339
#  up%: 0.27823691460055094
# 4 4.9
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 5.0
# accuracy: 0.5316804407713499
# log_return: -0.08965296166208463
# simple_return: 0.9142484094720297
#  up%: 0.2809917355371901
# 4 5.0
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 5.1
# accuracy: 0.5289256198347108
# log_return: -0.09478445902495215
# simple_return: 0.9095689627225104
#  up%: 0.2837465564738292
# 4 5.1
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 5.2
# accuracy: 0.5289256198347108
# log_return: -0.10226466732879057
# simple_return: 0.9027905808748935
#  up%: 0.2837465564738292
# 4 5.2
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 5.3
# accuracy: 0.5261707988980716
# log_return: -0.10421290015749245
# simple_return: 0.9010334468366821
#  up%: 0.2865013774104683
# 4 5.3
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 5.4
# accuracy: 0.5289256198347108
# log_return: -0.10226466732879057
# simple_return: 0.9027905808748935
#  up%: 0.2837465564738292
# 4 5.4
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 5.5
# accuracy: 0.5289256198347108
# log_return: -0.10226466732879057
# simple_return: 0.9027905808748935
#  up%: 0.2837465564738292
# 4 5.5
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 5.6
# accuracy: 0.5261707988980716
# log_return: -0.13023395787711425
# simple_return: 0.8778900176076077
#  up%: 0.2809917355371901
# 4 5.6
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 5.7
# accuracy: 0.5261707988980716
# log_return: -0.07914056921953641
# simple_return: 0.9239100420030377
#  up%: 0.2865013774104683
# 4 5.7
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 5.8
# accuracy: 0.5289256198347108
# log_return: -0.07107979253518057
# simple_return: 0.9313875713869547
#  up%: 0.2837465564738292
# 4 5.8
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 5.9
# accuracy: 0.5289256198347108
# log_return: -0.07107979253518057
# simple_return: 0.9313875713869547
#  up%: 0.2837465564738292
# 4 5.9
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 6.0
# accuracy: 0.5289256198347108
# log_return: -0.07107979253518057
# simple_return: 0.9313875713869547
#  up%: 0.2837465564738292
# 4 6.0
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 6.1
# accuracy: 0.5289256198347108
# log_return: -0.07107979253518057
# simple_return: 0.9313875713869547
#  up%: 0.2837465564738292
# 4 6.1
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 6.2
# accuracy: 0.5289256198347108
# log_return: -0.07388756961699172
# simple_return: 0.9287761106252143
#  up%: 0.2837465564738292
# 4 6.2
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 6.3
# accuracy: 0.5261707988980716
# log_return: -0.09559417812198323
# simple_return: 0.9088327654600422
#  up%: 0.2809917355371901
# 4 6.3
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 6.4
# accuracy: 0.5234159779614325
# log_return: -0.10108545437024763
# simple_return: 0.9038557911581614
#  up%: 0.27823691460055094
# 4 6.4
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 6.5
# accuracy: 0.5234159779614325
# log_return: -0.10108545437024763
# simple_return: 0.9038557911581614
#  up%: 0.27823691460055094
# 4 6.5
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 6.6
# accuracy: 0.5261707988980716
# log_return: -0.09741542247878834
# simple_return: 0.9071790652678408
#  up%: 0.2809917355371901
# 4 6.6
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 6.7
# accuracy: 0.5261707988980716
# log_return: -0.09741542247878834
# simple_return: 0.9071790652678408
#  up%: 0.2809917355371901
# 4 6.7
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 6.8
# accuracy: 0.5234159779614325
# log_return: -0.10108545437024763
# simple_return: 0.9038557911581614
#  up%: 0.27823691460055094
# 4 6.8
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 6.9
# accuracy: 0.5234159779614325
# log_return: -0.10108545437024763
# simple_return: 0.9038557911581614
#  up%: 0.27823691460055094
# 4 6.9
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 7.0
# accuracy: 0.5234159779614325
# log_return: -0.10108545437024763
# simple_return: 0.9038557911581614
#  up%: 0.27823691460055094
# 4 7.0
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 7.1
# accuracy: 0.5261707988980716
# log_return: -0.015034940196535396
# simple_return: 0.9850775201995974
#  up%: 0.2699724517906336
# 4 7.1
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 7.2
# accuracy: 0.5261707988980716
# log_return: -0.015034940196535396
# simple_return: 0.9850775201995974
#  up%: 0.2699724517906336
# 4 7.2
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 7.3
# accuracy: 0.5261707988980716
# log_return: -0.05018007647372566
# simple_return: 0.9510581458823335
#  up%: 0.2644628099173554
# 4 7.3
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 7.4
# accuracy: 0.5261707988980716
# log_return: -0.09344281219319267
# simple_return: 0.9107901020252797
#  up%: 0.25895316804407714
# 4 7.4
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 7.5
# accuracy: 0.5261707988980716
# log_return: -0.09344281219319267
# simple_return: 0.9107901020252797
#  up%: 0.25895316804407714
# 4 7.5
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 7.6
# accuracy: 0.5261707988980716
# log_return: -0.09344281219319267
# simple_return: 0.9107901020252797
#  up%: 0.25895316804407714
# 4 7.6
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# SVC Poly with degree: 4 C: 7.7
# accuracy: 0.5316804407713499
# log_return: -0.062236726034441026
# simple_return: 0.9396604183755317
#  up%: 0.2534435261707989
# 4 7.7
# Current Best Ret: degree: 1 C: 2.3 log ret: 0.5977849059084708 simple ret: 1.8180871027450243
# ---
# ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[162], line 20
#      18 print("---")
#      19 model = SVC(kernel='poly', degree = degree, C = C)
# ---> 20 acc, log_ret, simple_ret = benchmark(f"SVC Poly with degree: {degree} C: {C}", model, log_rets, X_train, y_train, X_test, y_test)
#      22 if acc > best_acc:
#      23     best_acc = acc
#
# Cell In[161], line 2, in benchmark(model_name, model, log_rets, X_train, y_train, X_test, y_test)
#       1 def benchmark(model_name, model, log_rets, X_train, y_train, X_test, y_test):
# ----> 2     pred = model.fit(X_train, y_train).predict(X_test)
#       3     acc = calculate_accuracy(pred, y_test)[0]
#       4     log_ret = calculate_return(pred, log_rets)[0]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/svm/_base.py:250, in BaseLibSVM.fit(self, X, y, sample_weight)
#     247     print("[LibSVM]", end="")
#     249 seed = rnd.randint(np.iinfo("i").max)
# --> 250 fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     251 # see comment on the other call to np.iinfo in this file
#     253 self.shape_fit_ = X.shape if hasattr(X, "shape") else (n_samples,)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/svm/_base.py:329, in BaseLibSVM._dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     315 libsvm.set_verbosity_wrap(self.verbose)
#     317 # we don't pass **self.get_params() to allow subclasses to
#     318 # add other parameters to __init__
#     319 (
#     320     self.support_,
#     321     self.support_vectors_,
#     322     self._n_support,
#     323     self.dual_coef_,
#     324     self.intercept_,
#     325     self._probA,
#     326     self._probB,
#     327     self.fit_status_,
#     328     self._num_iter,
# --> 329 ) = libsvm.fit(
#     330     X,
#     331     y,
#     332     svm_type=solver_type,
#     333     sample_weight=sample_weight,
#     334     # TODO(1.4): Replace "_class_weight" with "class_weight_"
#     335     class_weight=getattr(self, "_class_weight", np.empty(0)),
#     336     kernel=kernel,
#     337     C=self.C,
#     338     nu=self.nu,
#     339     probability=self.probability,
#     340     degree=self.degree,
#     341     shrinking=self.shrinking,
#     342     tol=self.tol,
#     343     cache_size=self.cache_size,
#     344     coef0=self.coef0,
#     345     gamma=self._gamma,
#     346     epsilon=self.epsilon,
#     347     max_iter=self.max_iter,
#     348     random_seed=random_seed,
#     349 )
#     351 self._warn_from_fit_status()
#
# KeyboardInterrupt:
